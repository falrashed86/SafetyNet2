# %%
pip install matplotlib numpy scikit-learn
# Out:
# Requirement already satisfied: matplotlib in d:\315\lib\site-packages (3.9.2)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy in d:\315\lib\site-packages (1.26.4)
# Requirement already satisfied: scikit-learn in d:\315\lib\site-packages (1.5.1)
# Requirement already satisfied: contourpy>=1.0.1 in d:\315\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in d:\315\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\315\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\315\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in d:\315\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in d:\315\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\315\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in d:\315\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: scipy>=1.6.0 in d:\315\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in d:\315\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\315\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: six>=1.5 in d:\315\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import matplotlib.pyplot as plt
import numpy as np

cm = np.array([
    [1544, 116, 482],
    [374, 26096, 2219],
    [310, 250, 599]
])

labels = ["HIGH", "LOW", "MEDIUM"]

plt.figure(figsize=(6, 5))
plt.imshow(cm)
plt.title("Confusion Matrix - Weighted LSTM")
plt.colorbar()

plt.xticks(np.arange(len(labels)), labels)
plt.yticks(np.arange(len(labels)), labels)

for i in range(len(labels)):
    for j in range(len(labels)):
        plt.text(j, i, cm[i, j],
                 ha="center", va="center")

plt.xlabel("Predicted Label")
plt.ylabel("True Label")

plt.tight_layout()
plt.savefig("confusion_matrix.png", dpi=300)
plt.show()
